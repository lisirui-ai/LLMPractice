# %% [markdown]
# # 使用 LlamaFactory 对 DeepSeekR1DistillLlama8B 进行 LoRA 微调

# %%
# !llamafactory-cli train lora_LlamaFactory_train.yaml
# Out:
# [INFO|2026-07-10 13:46:44] llamafactory.hparams.parser:523 >> Process rank: 0, world size: 1, device: cuda:0, distributed training: False, compute dtype: torch.bfloat16
# [INFO|tokenization_utils_base.py:2066] 2026-07-10 13:46:44,739 >> loading file tokenizer.model
# [INFO|tokenization_utils_base.py:2066] 2026-07-10 13:46:44,739 >> loading file tokenizer.json
# [INFO|tokenization_utils_base.py:2066] 2026-07-10 13:46:44,739 >> loading file added_tokens.json
# [INFO|tokenization_utils_base.py:2066] 2026-07-10 13:46:44,739 >> loading file special_tokens_map.json
# [INFO|tokenization_utils_base.py:2066] 2026-07-10 13:46:44,739 >> loading file tokenizer_config.json
# [INFO|tokenization_utils_base.py:2066] 2026-07-10 13:46:44,739 >> loading file chat_template.jinja
# [INFO|tokenization_utils_base.py:2337] 2026-07-10 13:46:45,087 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...
